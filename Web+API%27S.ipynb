# %% [markdown]
# # IS362_ASSIGNMENT12
# ## David Vayman
# ### Import all libraries

# %%
import pandas as pd
import json
import urllib.request
from pandas.io.json import json_normalize

# %% [markdown]
# ## Read the API data

# %%
api_key = '8dee647b0f3c4fb1854757f3df551137'
url = url = 'https://api.nytimes.com/svc/mostpopular/v2/mostviewed/Movies/1.json?'
string = url+'&api-key='+api_key

response = str(urllib.request.urlopen(string).read(), 'utf-8')

# %% [markdown]
# ## Put the API data in to a Dataframe

# %%
mostviews_movies = pd.read_json(response)
mostviews_movies
# Out:
#                                             copyright  num_results  \
# 0   Copyright (c) 2017 The New York Times Company....           23
# 1   Copyright (c) 2017 The New York Times Company....           23
# 2   Copyright (c) 2017 The New York Times Company....           23
# 3   Copyright (c) 2017 The New York Times Company....           23
# 4   Copyright (c) 2017 The New York Times Company....           23
# 5   Copyright (c) 2017 The New York Times Company....           23
# 6   Copyright (c) 2017 The New York Times Company....           23
# 7   Copyright (c) 2017 The New York Times Company....           23
# 8   Copyright (c) 2017 The New York Times Company....           23
# 9   Copyright (c) 2017 The New York Times Company....           23
# 10  Copyright (c) 2017 The New York Times Company....           23
# 11  Copyright (c) 2017 The New York Times Company....           23
# 12  Copyright (c) 2017 The New York Times Company....           23
# ...

# %% [markdown]
# ## Sort and display the data in descending order to show the most popular and most viewed movies

# %%
data = json.loads(response)
most_viewed = json_normalize(data['results'])
most_viewed.sort_values(by=["views"], ascending=False)
# Out:
#                                              abstract  \
# 19  The women, part of the giant step for mankind,...
# 18  Five new movies arrived in wide release over t...
# 17  The film, written and directed by Kenneth Lone...
# 16  With Lee Daniels and Jeffrey Wright as jurors,...
# 15  There are so many services to stream films tha...
# 14  Jane Jacobs fought against Robert Moses’ plans...
# 13  Ben Wheatley’s formula for action-movie succes...
# 12  Politicians, the police, victims and survivors...
# 11  ‘Norman: The Moderate Rise and Tragic Fall of ...
# 10  The fast-faced documentary “Tomorrow” profiles...
# 9   Inspired by a true story, “The Happiest Day in...
# 8   The monumental documentary about war and guilt...
# 7   The French director Bruno Dumont’s look at two...
# 6   Lydia Tenaglia’s documentary is a portrait of ...
# 5   Disneynature’s latest documentary visits remot...
# 4   Charlie Hunnam stars in this period adventure ...
# ...
